# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/dataset/yolo8-entrenamiento.zip -d /content/dataset
# Out:
# Archive:  /content/drive/MyDrive/dataset/yolo8-entrenamiento.zip
#   inflating: /content/dataset/README.dataset.txt
#   inflating: /content/dataset/README.roboflow.txt
#   inflating: /content/dataset/data.yaml
#    creating: /content/dataset/test/
#    creating: /content/dataset/test/images/
#  extracting: /content/dataset/test/images/IMG_1109_jpeg_jpeg.rf.19d6f750faf32b8c3934fc1c696beb4e.jpg
#  extracting: /content/dataset/test/images/IMG_1124_jpeg_jpeg.rf.ca4c66ddf65596156fa939ee9a081eec.jpg
#  extracting: /content/dataset/test/images/IMG_1134_jpeg_jpeg.rf.b3a04efeeeed52eb00cd32ec2d36394d.jpg
#  extracting: /content/dataset/test/images/IMG_1149_jpeg_jpeg.rf.984a3bdc61e46582e86972b24f264bf1.jpg
#  extracting: /content/dataset/test/images/kiwi132_jpg.rf.674fa198ca7f1c013977cefcecc97119.jpg
#  extracting: /content/dataset/test/images/kiwi137_jpg.rf.c2c93e5e2bcc91943f23f32059b60ac9.jpg
#  extracting: /content/dataset/test/images/kiwi146_jpg.rf.3b56680406b1a1ee6a38a7f41bc8afbd.jpg
# ...

# %%
# !ls /content/dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !cat /content/dataset/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 2
# names: ['kiwi', 'strawberry']
#
# roboflow:
#   workspace: andreseb
#   project: yolo-training-q2chv
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/andreseb/yolo-training-q2chv/dataset/1

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # modelo base preentrenado
model.train(data='/content/dataset/data.yaml', epochs=50, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Cargar tu modelo entrenado (el que está en runs/detect/train)
model = YOLO('/content/runs/detect/train/weights/best.pt')
 # tu modelo entrenado

results = model.predict(
    source='/content/drive/MyDrive/dataset/.jpg',
    show=True,
    save = True

)
# Out:
# image 1/1 /content/drive/MyDrive/kiwi-fresa.jpg: 384x640 (no detections), 126.3ms
# Speed: 4.0ms preprocess, 126.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# !pip install opencv-python

# %%
# !ls /content/runs/detect/predict/
# Out:
# kiwi-fresa.jpg
